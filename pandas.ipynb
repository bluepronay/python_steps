# %% [markdown]
# Pandas used for 2D tabular data structures,separated by commas with labelled aceess
# To import the pandas library, if not installed, pip install pandas

# %%
import pandas as pd

# %% [markdown]
# boston dataset is already a dataset in sklearn, we will use that, first
# do
# pip install scikit-learn

# %% [markdown]
# Importing a data from csv files, to pandas dataframe

# %%
#csv file to panas dataframe
#pd.read_csv('path of csv file')

diabetes_df=pd.read_csv('./datasets/diabetes.csv')

type(diabetes_df)   #its type
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Let's analyse it

# %%
diabetes_df.head()   #to print first five enteries
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape     #to know the no of rows and columns
# Out:
# (768, 9)

# %% [markdown]
# To load a data from a excel file to a pandas dataframe

# %%
salary_df=pd.read_excel('./Datasets/Salary.xlsx')

# %% [markdown]
# Exporting a dataframe to csv file, same with excel

# %%
diabetes_df.to_csv('diabetes.csv')

# %% [markdown]
# Create a dataframe with random values

# %%
import random
import numpy as np

# %%
random_df=pd.DataFrame(np.random.random((20,10)))   #random values from 0 to 1

# %%
random_df.shape
# Out:
# (20, 10)

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.370878  0.416573  0.840655  0.342635  0.319302  0.161673  0.232584
# 1  0.450997  0.535066  0.344988  0.845406  0.959681  0.754408  0.594151
# 2  0.775801  0.062163  0.921956  0.060239  0.080791  0.324375  0.315963
# 3  0.758888  0.274558  0.684218  0.441575  0.477123  0.047837  0.089511
# 4  0.579421  0.128058  0.518490  0.568366  0.823425  0.894604  0.795164
#
#           7         8         9
# 0  0.518555  0.759252  0.545545
# 1  0.503005  0.412511  0.253757
# 2  0.511898  0.032553  0.801137
# 3  0.234048  0.992322  0.382691
# 4  0.803515  0.365494  0.228600

# %%
print(random_df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.370878  0.416573  0.840655  0.342635  0.319302  0.161673  0.232584
# 1   0.450997  0.535066  0.344988  0.845406  0.959681  0.754408  0.594151
# 2   0.775801  0.062163  0.921956  0.060239  0.080791  0.324375  0.315963
# 3   0.758888  0.274558  0.684218  0.441575  0.477123  0.047837  0.089511
# 4   0.579421  0.128058  0.518490  0.568366  0.823425  0.894604  0.795164
# 5   0.256291  0.947811  0.710761  0.369114  0.354767  0.852980  0.638786
# 6   0.118385  0.245648  0.504671  0.300254  0.038865  0.066652  0.090944
# 7   0.813116  0.183125  0.176072  0.196927  0.179757  0.295821  0.284819
# 8   0.141325  0.107775  0.302399  0.845133  0.081257  0.180730  0.073661
# 9   0.249527  0.707911  0.411018  0.199664  0.395968  0.225950  0.278970
# 10  0.253878  0.454458  0.183898  0.282993  0.981874  0.948272  0.128310
# 11  0.563862  0.130864  0.102847  0.475890  0.211124  0.211859  0.798418
# ...

# %%
random_df.tail()       #last five values
# Out:
#            0         1         2         3         4         5         6  \
# 15  0.235463  0.712790  0.972083  0.945758  0.071137  0.560892  0.626328
# 16  0.676184  0.082154  0.360700  0.320559  0.354518  0.447247  0.204301
# 17  0.479287  0.849730  0.104967  0.574780  0.361536  0.715519  0.082662
# 18  0.223469  0.305195  0.548975  0.599890  0.715751  0.472736  0.830162
# 19  0.819102  0.595503  0.114162  0.962479  0.551225  0.325751  0.724697
#
#            7         8         9
# 15  0.859453  0.116787  0.043020
# 16  0.911170  0.256177  0.528594
# 17  0.377877  0.233901  0.759024
# 18  0.879006  0.391269  0.253510
# 19  0.611576  0.691684  0.453612

# %% [markdown]
# Everything about the csv file,very useful
# also tells us size

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# To find the no of missing values in a csv file

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# To count a particular column,enteries for ex let's find how many diabetic

# %%
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_df.value_counts('Age')         #group kar chuka hai, age k basis pe
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 38    16
# 36    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 44     8
# 51     8
# 50     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 53     5
# 57     5
# 48     5
# 60     5
# 55     4
# 63     4
# 62     4
# 66     4
# 56     3
# 65     3
# 59     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %% [markdown]
# To group the enteries based on a particular attribute , and then find the mean of every column

# %%
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
diabetes_df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %% [markdown]
# To describe everything, all these min,max,std,mean,mode , 25% etc

# %%
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manupulating a dataframe

# %%
random_values = [random.randint(3, 3000) for i in range(len(diabetes_df))]
print(random_values)
# Out:
# [1168, 420, 106, 95, 2643, 2127, 567, 2357, 2602, 471, 1626, 2794, 33, 1155, 1201, 1152, 2785, 899, 150, 1393, 1128, 815, 451, 374, 1282, 1597, 2440, 1344, 2783, 1430, 1970, 563, 676, 2674, 2036, 1300, 1711, 908, 877, 2402, 36, 262, 719, 2730, 2426, 2659, 1036, 2746, 424, 1345, 2570, 2517, 1065, 2989, 685, 2761, 965, 646, 873, 2341, 1127, 106, 2571, 1118, 1274, 2636, 1946, 2480, 132, 2706, 602, 2811, 2421, 1889, 2162, 453, 1744, 61, 993, 2874, 1120, 2247, 2227, 1308, 1781, 1276, 2725, 942, 35, 2119, 486, 1250, 905, 910, 2122, 1231, 1035, 1168, 2701, 613, 2634, 2723, 542, 1804, 1936, 2789, 313, 1931, 1384, 2758, 742, 670, 1638, 1482, 1775, 2396, 901, 2083, 1687, 399, 2628, 2374, 356, 1551, 1081, 1257, 2431, 2459, 1634, 661, 399, 1844, 613, 84, 90, 97, 1598, 1908, 1181, 2509, 768, 2811, 2507, 2767, 1575, 1979, 820, 294, 1877, 912, 1684, 1622, 2303, 2743, 1451, 2413, 1104, 754, 2077, 1145, 2030, 951, 250, 1759, 2641, 1024, 2613, 1594, 1390, 1786, 2436, 970, 325, 867, 116, 2761, 115, 257
# ...

# %% [markdown]
# 1. Adding a column

# %%
diabetes_df['Random_Value'] = random_values

# %%
diabetes_df.shape
diabetes_df.head()  #u can see new column
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Random_Value
# 0                     0.627   50        1          1168
# 1                     0.351   31        0           420
# 2                     0.672   32        1           106
# 3                     0.167   21        0            95
# 4                     2.288   33        1          2643

# %% [markdown]
# 2. To remove a row, axis=0, and index should be given

# %%
diabetes_df.drop(index=2,axis=0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Random_Value
# ...

# %% [markdown]
# 3. To remove a column

# %%
diabetes_df.drop(columns='Age',axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome  Random_Value
# 0                       0.627        1          1168
# ...

# %% [markdown]
# It's temporarily only, if u want to do it permanently, make a new csv file variable

# %%
diabetes_df2=diabetes_df.drop(columns='Age',axis=1)
diabetes_df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Outcome  Random_Value
# 0                     0.627        1          1168
# 1                     0.351        0           420
# 2                     0.672        1           106
# 3                     0.167        0            95
# 4                     2.288        1          2643

# %% [markdown]
# 4. Locating a row using index values

# %%
diabetes_df.iloc[2]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Random_Value                106.000
# Name: 2, dtype: float64

# %% [markdown]
# 5. Locating a particular column

# %%
diabetes_df.iloc[:,3]
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64

# %% [markdown]
# 6. Correlation : the relation between two attributes, it will tell direct relationship or indirect
# if negative then inidirect
# if positive then direct

# %%
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
# Random_Value                -0.003268  0.029869       0.033627      -0.042681
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# ...
